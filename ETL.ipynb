# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 from sqlalchemy import create_engine
 engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/employees')
 connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4b9b473e6bab> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/employees')
#       3 connection = engine.connect()
#
# NameError: name 'username' is not defined

# %%
csv_2020 = "./Resources/2020Data.csv"
data_2020_df = pd.read_csv(csv_2020)
data_2020_df.head()
# Out:
#   Country_name  Ladder_score  Social_support  Healthy_life_expectancy  \
# 0      Finland        7.8087        0.954330                71.900825
# 1      Denmark        7.6456        0.955991                72.402504
# 2  Switzerland        7.5599        0.942847                74.102448
# 3      Iceland        7.5045        0.974670                73.000000
# 4       Norway        7.4880        0.952487                73.200783
#
#    Freedom_to_make_life_choices  Generosity   Perceptions_of_corruption
# 0                      0.949172    -0.059482                   0.195445
# 1                      0.951444     0.066202                   0.168489
# 2                      0.921337     0.105911                   0.303728
# 3                      0.948892     0.246944                   0.711710
# 4                      0.955750     0.134533                   0.263218

# %%
csv_2021 = "./Resources/2021Data.csv"
data_2021_df = pd.read_csv(csv_2021)
data_2021_df.head()
# Out:
#   Country_name  Ladder_score  Social_support  Healthy_life_expectancy  \
# 0      Finland         7.842           0.954                     72.0
# 1      Denmark         7.620           0.954                     72.7
# 2  Switzerland         7.571           0.942                     74.4
# 3      Iceland         7.554           0.983                     73.0
# 4  Netherlands         7.464           0.942                     72.4
#
#    Freedom_to_make_life_choices  Generosity   Perceptions_of_corruption
# 0                         0.949       -0.098                      0.186
# 1                         0.946        0.030                      0.179
# 2                         0.919        0.025                      0.292
# 3                         0.955        0.160                      0.673
# 4                         0.913        0.175                      0.338

# %%
connection_string = "postgres:postgres@localhost:5432/ETL-Project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['2020Data', '2021Data']

# %%
data_2021_df
# Out:
#                  Country_name  Ladder_score  Social_support  \
# 0                     Finland        7.8087        0.954330
# 1                     Denmark        7.6456        0.955991
# 2                 Switzerland        7.5599        0.942847
# 3                     Iceland        7.5045        0.974670
# 4                      Norway        7.4880        0.952487
# ..                        ...           ...             ...
# 148  Central African Republic        3.4759        0.319460
# 149                    Rwanda        3.3123        0.540835
# 150                  Zimbabwe        3.2992        0.763093
# 151               South Sudan        2.8166        0.553707
# 152               Afghanistan        2.5669        0.470367
#
#      Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity   \
# 0                  71.900825                      0.949172    -0.059482
# 1                  72.402504                      0.951444     0.066202
# ...

# %%
data_2021_df.to_sql ('Data2021', con=engine, if_exists='append', index=False)

# %%
data_2020_df.to_sql ('Data2020', con=engine, if_exists='append', index=False)
